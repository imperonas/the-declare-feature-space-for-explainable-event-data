# %% [markdown]
# # DECLARE Constraint Discovery and Analysis
#
# This notebook performs DECLARE constraint discovery on event log data to identify declarative process constraints and analyze their satisfaction across traces.

# %%
from Declare4Py.D4PyEventLog import D4PyEventLog
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareAnalyzer import (
    MPDeclareAnalyzer,
)
from Declare4Py.ProcessMiningTasks.Discovery.DeclareMiner import DeclareMiner
from Declare4Py.ProcessModels.DeclareModel import DeclareModel
import pm4py as pm
from pm4py.objects.conversion.log import converter as log_converter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the clustered event log from CSV, filter by cluster number, and convert to both pm4py and D4Py formats for processing.

# %%
log_path = "/home/cwrk/Work/xai-2026-declarative-feature-space/DomesticDeclarations_clustered.csv"
log = pd.read_csv(log_path)

cols = ["case:concept:name", "concept:name", "time:timestamp", "cluster"]
print("Number of clusters: ", log["cluster"].nunique())
cluster_number = -1
log = log.loc[log['cluster'] == cluster_number, cols]

print()

log["time:timestamp"] = pd.to_datetime(log["time:timestamp"])

log = pm.convert.convert_to_event_log(log)
pm.write_xes(log, f"DomesticDeclarations_cluster_{cluster_number}.xes")
log = pm.read_xes(f"DomesticDeclarations_cluster_{cluster_number}.xes")

# legacy pm4py log
parameters = {
    log_converter.Variants.TO_EVENT_LOG.value.Parameters.CASE_ID_KEY: "case:concept:name"
}
log = log_converter.apply(
    log,
    variant=log_converter.Variants.TO_EVENT_LOG,
    parameters=parameters,
)

case_ids = [trace.attributes["concept:name"] for trace in log]
# d4py log
log = D4PyEventLog(log=log, case_name="case:concept:name")
# Out:
# Number of clusters:  6
# exporting log, completed traces ::   0%|          | 0/780 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/780 [00:00<?, ?it/s]

# %% [markdown]
# ## Discover DECLARE Model and Check Conformance
#
# Run DECLARE constraint discovery with specified parameters (min support 5%, max cardinality 2), then perform conformance checking to analyze how traces satisfy the discovered constraints.

# %%
discovery = DeclareMiner(
    log=log,
    consider_vacuity=False,
    min_support=0.05,
    itemsets_support=0.05,
    max_declare_cardinality=2,
)
model = discovery.run()
checker = MPDeclareAnalyzer(
    log=log, declare_model=model, consider_vacuity=False
)
results = checker.run()
# Out:
# Computing discovery ...

# %% [markdown]
# ## Extract Conformance Metrics
#
# Extract key metrics from conformance checking results:
# - **Violations**: number of constraint violations per trace
# - **Activations**: how many times constraints were activated
# - **Fulfillments**: number of successful constraint satisfactions
# - **Pendings**: constraints still pending
# - **Satisfaction**: binary satisfaction state per constraint

# %%
# ["num_activations", "num_violations", "num_fulfillments", "num_pendings", "state"]
violations = results.get_metric("num_violations")
activations = results.get_metric("num_activations")
fullfillments = results.get_metric("num_fulfillments")
pendings = results.get_metric("num_pendings")
statisfaction = results.get_metric("state")

constraints = list(statisfaction.columns)
n_traces = statisfaction.shape[0]

# sum over all columns of fullfillments, violations, activations, pendings
violations_sum = violations.sum()
activations_sum = activations.sum()
fullfillments_sum = fullfillments.sum()
pendings_sum = pendings.sum()
statisfaction_sum = statisfaction.sum()

# %% [markdown]
# ## Calculate Constraint Support
#
# Compute support (satisfaction rate) for each constraint across all traces and save results to CSV.

# %%
support = {}
for c in constraints:
    support[c] = statisfaction_sum[c] / n_traces

support = pd.Series(support)
support = support.sort_values(ascending=False)
support.to_csv(f"bpic2020_support_cluster_{cluster_number}.csv", header=True)
support
# Out:
# Absence2[Payment Handled] | |                                                                              1.000000
# Absence2[Declaration SAVED by EMPLOYEE] | |                                                                1.000000
# Absence2[Request Payment] | |                                                                              1.000000
# Absence2[Declaration REJECTED by BUDGET OWNER] | |                                                         0.998718
# Absence2[Declaration REJECTED by PRE_APPROVER] | |                                                         0.993590
#                                                                                                              ...
# Alternate Response[Declaration REJECTED by BUDGET OWNER, Declaration FINAL_APPROVED by SUPERVISOR] | |     0.052564
# Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | |               0.052564
# Responded Existence[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | |    0.051282
# Responded Existence[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | |    0.051282
# Chain Response[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by SUPERVISOR] | |             0.051282
# Length: 934, dtype: float64

# %% [markdown]
# ## Create Feature Spaces with Support Filtering
#
# Build two feature representations:
# - **Boolean feature space**: binary satisfaction (True/False) per constraint
# - **Quantitative feature space**: number of fulfillments per constraint
#
# Filter to keep only constraints with support ≥ 50% and analyze their value distributions.

# %%
bool_feature_space = statisfaction.astype(bool)
qual_feature_space = fullfillments

support_threshhold = 0.5
cols_to_keep = support[support >= support_threshhold].index
bool_feature_space = bool_feature_space[cols_to_keep]
qual_feature_space = qual_feature_space[cols_to_keep]

bool_unique_series = bool_feature_space.apply(lambda col: col.value_counts().to_dict())
for c in bool_unique_series.index:
    print(c, bool_unique_series[c])

qual_unique_series = qual_feature_space.apply(lambda col: col.value_counts().to_dict())
for c in qual_unique_series.index:
    print(c, qual_unique_series[c])
# Out:
# Absence2[Payment Handled] | | {True: 780}
# Absence2[Declaration SAVED by EMPLOYEE] | | {True: 780}
# Absence2[Request Payment] | | {True: 780}
# Absence2[Declaration REJECTED by BUDGET OWNER] | | {True: 779, False: 1}
# Absence2[Declaration REJECTED by PRE_APPROVER] | | {True: 775, False: 5}
# Absence2[Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 771, False: 9}
# Absence2[Declaration APPROVED by PRE_APPROVER] | | {True: 770, False: 10}
# Absence2[Declaration REJECTED by SUPERVISOR] | | {True: 768, False: 12}
# Absence2[Declaration APPROVED by BUDGET OWNER] | | {True: 767, False: 13}
# Absence2[Declaration REJECTED by ADMINISTRATION] | | {True: 761, False: 19}
# Absence1[Declaration REJECTED by BUDGET OWNER] | | {True: 724, False: 56}
# Absence2[Declaration REJECTED by EMPLOYEE] | | {True: 712, False: 68}
# Absence1[Declaration REJECTED by PRE_APPROVER] | | {True: 699, False: 81}
# Absence1[Declaration APPROVED by PRE_APPROVER] | | {True: 697, False: 83}
# Absence1[Declaration APPROVED by BUDGET OWNER] | | {True: 666, False: 114}
# Choice[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {True: 646, False: 134}
# Choice[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {True: 646, False: 134}
# Choice[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {True: 646, False: 134}
# Choice[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {True: 646, False: 134}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 645, False: 135}
# Not Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {True: 645, False: 135}
# Not Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Absence1[Declaration SAVED by EMPLOYEE] | | {True: 645, False: 135}
# Existence1[Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 645, False: 135}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 645, False: 135}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 645, False: 135}
# Init[Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 644, False: 136}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 644, False: 136}
# Not Chain Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 643, False: 137}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 641, False: 139}
# Not Chain Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 638, False: 142}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 636, False: 144}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 635, False: 145}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 635, False: 145}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 634, False: 146}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 618, False: 162}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {True: 611, False: 169}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {True: 611, False: 169}
# Choice[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {True: 609, False: 171}
# Choice[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {True: 609, False: 171}
# Choice[Declaration REJECTED by EMPLOYEE, Request Payment] | | {True: 605, False: 175}
# Choice[Request Payment, Declaration REJECTED by EMPLOYEE] | | {True: 605, False: 175}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 604, False: 176}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {True: 604, False: 176}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 603, False: 177}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 603, False: 177}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 603, False: 177}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 603, False: 177}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 602, False: 178}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 602, False: 178}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 602, False: 178}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 599, False: 181}
# Existence1[Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 599, False: 181}
# Not Chain Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Request Payment] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Alternate Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {True: 599, False: 181}
# Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {True: 598, False: 182}
# Not Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {True: 598, False: 182}
# Not Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {True: 598, False: 182}
# Not Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 596, False: 184}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 596, False: 184}
# Not Chain Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 595, False: 185}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 594, False: 186}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 592, False: 188}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 589, False: 191}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 589, False: 191}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 589, False: 191}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 589, False: 191}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 588, False: 192}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 588, False: 192}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 586, False: 194}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 573, False: 207}
# Absence2[Declaration APPROVED by ADMINISTRATION] | | {True: 573, False: 207}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 572, False: 208}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 570, False: 210}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 568, False: 212}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 564, False: 216}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 562, False: 218}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Absence1[Declaration REJECTED by ADMINISTRATION] | | {True: 545, False: 235}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 544, False: 236}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 544, False: 236}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 543, False: 237}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 543, False: 237}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 543, False: 237}
# Exactly1[Declaration REJECTED by EMPLOYEE] | | {True: 531, False: 249}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 531, False: 249}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 531, False: 249}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 531, False: 249}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 531, False: 249}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 522, False: 258}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 522, False: 258}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 522, False: 258}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 519, False: 261}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 519, False: 261}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 518, False: 262}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 518, False: 262}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 518, False: 262}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 518, False: 262}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 504, False: 276}
# Absence1[Declaration APPROVED by ADMINISTRATION] | | {True: 501, False: 279}
# Absence1[Declaration REJECTED by SUPERVISOR] | | {True: 500, False: 280}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 493, False: 287}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 493, False: 287}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 489, False: 291}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {True: 474, False: 306}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {True: 474, False: 306}
# Absence1[Request Payment] | | {True: 460, False: 320}
# Absence1[Payment Handled] | | {True: 456, False: 324}
# Exclusive Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {True: 434, False: 346}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {True: 434, False: 346}
# Not Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 431, False: 349}
# Absence1[Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 430, False: 350}
# Not Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 428, False: 352}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 427, False: 353}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by SUPERVISOR] | | {True: 427, False: 353}
# Absence2[Declaration SUBMITTED by EMPLOYEE] | | {True: 423, False: 357}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration APPROVED by ADMINISTRATION] | | {True: 412, False: 368}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 412, False: 368}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 410, False: 370}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Choice[Declaration REJECTED by SUPERVISOR, Payment Handled] | | {True: 400, False: 380}
# Choice[Payment Handled, Declaration REJECTED by SUPERVISOR] | | {True: 400, False: 380}
# Choice[Request Payment, Declaration REJECTED by SUPERVISOR] | | {True: 397, False: 383}
# Choice[Declaration REJECTED by SUPERVISOR, Request Payment] | | {True: 397, False: 383}
# Absence2[Payment Handled] | | {}
# Absence2[Declaration SAVED by EMPLOYEE] | | {}
# Absence2[Request Payment] | | {}
# Absence2[Declaration REJECTED by BUDGET OWNER] | | {}
# Absence2[Declaration REJECTED by PRE_APPROVER] | | {}
# Absence2[Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Absence2[Declaration APPROVED by PRE_APPROVER] | | {}
# Absence2[Declaration REJECTED by SUPERVISOR] | | {}
# Absence2[Declaration APPROVED by BUDGET OWNER] | | {}
# Absence2[Declaration REJECTED by ADMINISTRATION] | | {}
# Absence1[Declaration REJECTED by BUDGET OWNER] | | {}
# Absence2[Declaration REJECTED by EMPLOYEE] | | {}
# Absence1[Declaration REJECTED by PRE_APPROVER] | | {}
# Absence1[Declaration APPROVED by PRE_APPROVER] | | {}
# Absence1[Declaration APPROVED by BUDGET OWNER] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {}
# Choice[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {}
# Choice[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Absence1[Declaration SAVED by EMPLOYEE] | | {}
# Existence1[Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Init[Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 5, 6: 1, 7: 1, 5: 1}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {2: 312, 1: 288, 0: 135, 3: 37, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 289, 0: 135, 3: 37, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {2: 314, 1: 288, 0: 135, 3: 35, 4: 5, 5: 1, 6: 1, 7: 1}
# Not Chain Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {2: 309, 1: 293, 0: 135, 3: 36, 4: 5, 5: 1, 7: 1}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 294, 0: 135, 3: 32, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {2: 304, 1: 297, 0: 135, 3: 36, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {1: 312, 2: 292, 0: 135, 3: 35, 4: 2, 5: 2, 6: 1, 7: 1}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {}
# Choice[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Request Payment] | | {}
# Choice[Request Payment, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {1: 323, 2: 284, 0: 135, 3: 34, 4: 2, 6: 1, 7: 1}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Existence1[Declaration REJECTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Request Payment] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Alternate Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {2: 307, 1: 246, 0: 181, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 182, 2: 62, 3: 5, 6: 1}
# Not Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 182, 2: 62, 3: 5, 6: 1}
# Not Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 182, 2: 62, 3: 5, 6: 1}
# Not Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {1: 331, 2: 296, 0: 135, 3: 17, 4: 1}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {1: 528, 0: 184, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 183, 2: 62, 3: 4, 6: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 536, 0: 181, 2: 57, 3: 5, 6: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {1: 295, 2: 282, 0: 160, 3: 35, 4: 4, 5: 2, 6: 1, 7: 1}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 280, 2: 272, 0: 191, 3: 33, 4: 2, 6: 1, 7: 1}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 320, 2: 274, 0: 148, 3: 33, 4: 3, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {1: 293, 2: 286, 0: 160, 3: 33, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 520, 0: 192, 2: 62, 3: 5, 6: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 542, 0: 182, 2: 52, 3: 3, 6: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {1: 556, 0: 181, 2: 40, 3: 3}
# Absence2[Declaration APPROVED by ADMINISTRATION] | | {}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {1: 360, 2: 248, 0: 135, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {1: 557, 0: 182, 2: 38, 3: 3}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 514, 0: 208, 2: 54, 3: 3, 6: 1}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 280, 2: 247, 0: 216, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 349, 2: 251, 0: 143, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 350, 2: 250, 0: 143, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 284, 2: 242, 0: 217, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 346, 2: 249, 0: 148, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 283, 2: 242, 0: 218, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Absence1[Declaration REJECTED by ADMINISTRATION] | | {}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 502, 0: 222, 2: 53, 3: 2, 6: 1}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 502, 0: 224, 2: 51, 3: 2, 6: 1}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 490, 0: 237, 2: 50, 3: 2, 6: 1}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Exactly1[Declaration REJECTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 294, 0: 235, 2: 222, 3: 26, 4: 1, 6: 1, 7: 1}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 282, 0: 249, 2: 220, 3: 26, 4: 1, 6: 1, 7: 1}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 459, 0: 258, 2: 57, 3: 5, 6: 1}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 456, 0: 261, 2: 57, 3: 5, 6: 1}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 456, 0: 261, 2: 57, 3: 5, 6: 1}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 455, 0: 262, 2: 57, 3: 5, 6: 1}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 455, 0: 262, 2: 57, 3: 5, 6: 1}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 455, 0: 273, 2: 50, 3: 1, 6: 1}
# Absence1[Declaration APPROVED by ADMINISTRATION] | | {}
# Absence1[Declaration REJECTED by SUPERVISOR] | | {}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 443, 0: 291, 2: 44, 3: 1, 6: 1}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {}
# Absence1[Request Payment] | | {}
# Absence1[Payment Handled] | | {}
# Exclusive Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {}
# Not Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {1: 483, 2: 144, 0: 135, 3: 16, 6: 1, 4: 1}
# Absence1[Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {1: 489, 0: 135, 2: 135, 3: 18, 6: 1, 4: 1, 5: 1}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by SUPERVISOR] | | {}
# Absence2[Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration APPROVED by ADMINISTRATION] | | {}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {0: 370, 2: 283, 1: 109, 3: 17, 4: 1}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {0: 329, 2: 304, 1: 125, 3: 20, 4: 2}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {0: 336, 2: 299, 1: 124, 3: 19, 4: 2}
# Choice[Declaration REJECTED by SUPERVISOR, Payment Handled] | | {}
# Choice[Payment Handled, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Request Payment, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Declaration REJECTED by SUPERVISOR, Request Payment] | | {}

# %% [markdown]
# Inspect Boolean Feature Space

# %%
bool_feature_space
# Out:
#      Absence2[Payment Handled] | |  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ..                             ...
# 775                           True
# 776                           True
# 777                           True
# 778                           True
# 779                           True
#
#      Absence2[Declaration SAVED by EMPLOYEE] | |  \
# 0                                           True
# 1                                           True
# 2                                           True
# 3                                           True
# 4                                           True
# ..                                           ...
# 775                                         True
# 776                                         True
# 777                                         True
# 778                                         True
# 779                                         True
#
#      Absence2[Request Payment] | |  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ..                             ...
# 775                           True
# 776                           True
# 777                           True
# 778                           True
# 779                           True
#
#      Absence2[Declaration REJECTED by BUDGET OWNER] | |  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                               True
# 777                                               True
# 778                                               True
# 779                                               True
#
#      Absence2[Declaration REJECTED by PRE_APPROVER] | |  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                               True
# 777                                               True
# 778                                               True
# 779                                               True
#
#      Absence2[Declaration FINAL_APPROVED by SUPERVISOR] | |  \
# 0                                                False
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                               True
# 777                                               True
# 778                                               True
# 779                                               True
#
#      Absence2[Declaration APPROVED by PRE_APPROVER] | |  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                               True
# 777                                               True
# 778                                               True
# 779                                               True
#
#      Absence2[Declaration REJECTED by SUPERVISOR] | |  \
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# ..                                                ...
# 775                                              True
# 776                                              True
# 777                                              True
# 778                                              True
# 779                                              True
#
#      Absence2[Declaration APPROVED by BUDGET OWNER] | |  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                               True
# 777                                               True
# 778                                               True
# 779                                               True
#
#      Absence2[Declaration REJECTED by ADMINISTRATION] | |  ...  \
# 0                                                 True     ...
# 1                                                 True     ...
# 2                                                 True     ...
# 3                                                 True     ...
# 4                                                 True     ...
# ..                                                 ...     ...
# 775                                               True     ...
# 776                                               True     ...
# 777                                               True     ...
# 778                                               True     ...
# 779                                               True     ...
#
#      Choice[Declaration APPROVED by ADMINISTRATION, Declaration FINAL_APPROVED by SUPERVISOR] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Choice[Declaration REJECTED by SUPERVISOR, Payment Handled] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Choice[Payment Handled, Declaration REJECTED by SUPERVISOR] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Choice[Request Payment, Declaration REJECTED by SUPERVISOR] | |  \
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
#      Choice[Declaration REJECTED by SUPERVISOR, Request Payment] | |
# 0                                                 True
# 1                                                False
# 2                                                 True
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 775                                               True
# 776                                              False
# 777                                              False
# 778                                               True
# 779                                              False
#
# [780 rows x 180 columns]

# %% [markdown]
# Inspect Quantitative Feature Space

# %%
qual_feature_space
# Out:
#     Absence2[Payment Handled] | | Absence2[Declaration SAVED by EMPLOYEE] | |  \
# 0                            None                                        None
# 1                            None                                        None
# 2                            None                                        None
# 3                            None                                        None
# 4                            None                                        None
# ..                            ...                                         ...
# 775                          None                                        None
# 776                          None                                        None
# 777                          None                                        None
# 778                          None                                        None
# 779                          None                                        None
#
#     Absence2[Request Payment] | |  \
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# ..                            ...
# 775                          None
# 776                          None
# 777                          None
# 778                          None
# 779                          None
#
#     Absence2[Declaration REJECTED by BUDGET OWNER] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Absence2[Declaration REJECTED by PRE_APPROVER] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Absence2[Declaration FINAL_APPROVED by SUPERVISOR] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Absence2[Declaration APPROVED by PRE_APPROVER] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Absence2[Declaration REJECTED by SUPERVISOR] | |  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ..                                               ...
# 775                                             None
# 776                                             None
# 777                                             None
# 778                                             None
# 779                                             None
#
#     Absence2[Declaration APPROVED by BUDGET OWNER] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Absence2[Declaration REJECTED by ADMINISTRATION] | |  ...  \
# 0                                                 None    ...
# 1                                                 None    ...
# 2                                                 None    ...
# 3                                                 None    ...
# 4                                                 None    ...
# ..                                                 ...    ...
# 775                                               None    ...
# 776                                               None    ...
# 777                                               None    ...
# 778                                               None    ...
# 779                                               None    ...
#
#     Choice[Declaration APPROVED by ADMINISTRATION, Declaration FINAL_APPROVED by SUPERVISOR] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                    3
# 1                                                    0
# 2                                                    2
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 775                                                  1
# 776                                                  0
# 777                                                  0
# 778                                                  1
# 779                                                  0
#
#     Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                    3
# 1                                                    0
# 2                                                    2
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 775                                                  1
# 776                                                  0
# 777                                                  0
# 778                                                  1
# 779                                                  0
#
#     Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | |  \
# 0                                                    3
# 1                                                    0
# 2                                                    2
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 775                                                  1
# 776                                                  0
# 777                                                  0
# 778                                                  1
# 779                                                  0
#
#     Choice[Declaration REJECTED by SUPERVISOR, Payment Handled] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Choice[Payment Handled, Declaration REJECTED by SUPERVISOR] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Choice[Request Payment, Declaration REJECTED by SUPERVISOR] | |  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
#     Choice[Declaration REJECTED by SUPERVISOR, Request Payment] | |
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 775                                               None
# 776                                               None
# 777                                               None
# 778                                               None
# 779                                               None
#
# [780 rows x 180 columns]

# %% [markdown]
# Analyze Boolean Feature Distribution

# %%
bool_unique_series = bool_feature_space.apply(lambda col: col.value_counts().to_dict())
for c in bool_unique_series.index:
    print(c, bool_unique_series[c])
# Out:
# Absence2[Payment Handled] | | {True: 780}
# Absence2[Declaration SAVED by EMPLOYEE] | | {True: 780}
# Absence2[Request Payment] | | {True: 780}
# Absence2[Declaration REJECTED by BUDGET OWNER] | | {True: 779, False: 1}
# Absence2[Declaration REJECTED by PRE_APPROVER] | | {True: 775, False: 5}
# Absence2[Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 771, False: 9}
# Absence2[Declaration APPROVED by PRE_APPROVER] | | {True: 770, False: 10}
# Absence2[Declaration REJECTED by SUPERVISOR] | | {True: 768, False: 12}
# Absence2[Declaration APPROVED by BUDGET OWNER] | | {True: 767, False: 13}
# Absence2[Declaration REJECTED by ADMINISTRATION] | | {True: 761, False: 19}
# Absence1[Declaration REJECTED by BUDGET OWNER] | | {True: 724, False: 56}
# Absence2[Declaration REJECTED by EMPLOYEE] | | {True: 712, False: 68}
# Absence1[Declaration REJECTED by PRE_APPROVER] | | {True: 699, False: 81}
# Absence1[Declaration APPROVED by PRE_APPROVER] | | {True: 697, False: 83}
# Absence1[Declaration APPROVED by BUDGET OWNER] | | {True: 666, False: 114}
# Choice[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {True: 646, False: 134}
# Choice[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {True: 646, False: 134}
# Choice[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {True: 646, False: 134}
# Choice[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {True: 646, False: 134}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 645, False: 135}
# Not Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {True: 645, False: 135}
# Not Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Absence1[Declaration SAVED by EMPLOYEE] | | {True: 645, False: 135}
# Existence1[Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 645, False: 135}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 645, False: 135}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 645, False: 135}
# Init[Declaration SUBMITTED by EMPLOYEE] | | {True: 645, False: 135}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 644, False: 136}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 644, False: 136}
# Not Chain Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 643, False: 137}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 641, False: 139}
# Not Chain Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 638, False: 142}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 636, False: 144}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 635, False: 145}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 635, False: 145}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 634, False: 146}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 618, False: 162}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {True: 611, False: 169}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {True: 611, False: 169}
# Choice[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {True: 609, False: 171}
# Choice[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {True: 609, False: 171}
# Choice[Declaration REJECTED by EMPLOYEE, Request Payment] | | {True: 605, False: 175}
# Choice[Request Payment, Declaration REJECTED by EMPLOYEE] | | {True: 605, False: 175}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 604, False: 176}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {True: 604, False: 176}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 603, False: 177}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 603, False: 177}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 603, False: 177}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 603, False: 177}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 602, False: 178}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 602, False: 178}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 602, False: 178}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 599, False: 181}
# Existence1[Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 599, False: 181}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 599, False: 181}
# Not Chain Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Request Payment] | | {True: 599, False: 181}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Alternate Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {True: 599, False: 181}
# Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 599, False: 181}
# Not Chain Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {True: 598, False: 182}
# Not Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {True: 598, False: 182}
# Not Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {True: 598, False: 182}
# Not Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 596, False: 184}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {True: 596, False: 184}
# Not Chain Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {True: 595, False: 185}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 594, False: 186}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 592, False: 188}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 589, False: 191}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 589, False: 191}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 589, False: 191}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 589, False: 191}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 588, False: 192}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 588, False: 192}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 586, False: 194}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 573, False: 207}
# Absence2[Declaration APPROVED by ADMINISTRATION] | | {True: 573, False: 207}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 572, False: 208}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {True: 570, False: 210}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 568, False: 212}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 564, False: 216}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 564, False: 216}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {True: 562, False: 218}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 562, False: 218}
# Absence1[Declaration REJECTED by ADMINISTRATION] | | {True: 545, False: 235}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 544, False: 236}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 544, False: 236}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 543, False: 237}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 543, False: 237}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {True: 543, False: 237}
# Exactly1[Declaration REJECTED by EMPLOYEE] | | {True: 531, False: 249}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 531, False: 249}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 531, False: 249}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 531, False: 249}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {True: 531, False: 249}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 522, False: 258}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 522, False: 258}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 522, False: 258}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {True: 519, False: 261}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 519, False: 261}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 518, False: 262}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {True: 518, False: 262}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 518, False: 262}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {True: 518, False: 262}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 504, False: 276}
# Absence1[Declaration APPROVED by ADMINISTRATION] | | {True: 501, False: 279}
# Absence1[Declaration REJECTED by SUPERVISOR] | | {True: 500, False: 280}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {True: 493, False: 287}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 493, False: 287}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {True: 489, False: 291}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {True: 474, False: 306}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {True: 474, False: 306}
# Absence1[Request Payment] | | {True: 460, False: 320}
# Absence1[Payment Handled] | | {True: 456, False: 324}
# Exclusive Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {True: 434, False: 346}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {True: 434, False: 346}
# Not Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 431, False: 349}
# Absence1[Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 430, False: 350}
# Not Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {True: 428, False: 352}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 427, False: 353}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by SUPERVISOR] | | {True: 427, False: 353}
# Absence2[Declaration SUBMITTED by EMPLOYEE] | | {True: 423, False: 357}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration APPROVED by ADMINISTRATION] | | {True: 412, False: 368}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration FINAL_APPROVED by SUPERVISOR] | | {True: 412, False: 368}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {True: 410, False: 370}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {True: 410, False: 370}
# Choice[Declaration REJECTED by SUPERVISOR, Payment Handled] | | {True: 400, False: 380}
# Choice[Payment Handled, Declaration REJECTED by SUPERVISOR] | | {True: 400, False: 380}
# Choice[Request Payment, Declaration REJECTED by SUPERVISOR] | | {True: 397, False: 383}
# Choice[Declaration REJECTED by SUPERVISOR, Request Payment] | | {True: 397, False: 383}

# %% [markdown]
# Analyze Quantitative Feature Distribution

# %%
qual_unique_series = qual_feature_space.apply(lambda col: col.value_counts().to_dict())
for c in qual_unique_series.index:
    print(c, qual_unique_series[c])
# Out:
# Absence2[Payment Handled] | | {}
# Absence2[Declaration SAVED by EMPLOYEE] | | {}
# Absence2[Request Payment] | | {}
# Absence2[Declaration REJECTED by BUDGET OWNER] | | {}
# Absence2[Declaration REJECTED by PRE_APPROVER] | | {}
# Absence2[Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Absence2[Declaration APPROVED by PRE_APPROVER] | | {}
# Absence2[Declaration REJECTED by SUPERVISOR] | | {}
# Absence2[Declaration APPROVED by BUDGET OWNER] | | {}
# Absence2[Declaration REJECTED by ADMINISTRATION] | | {}
# Absence1[Declaration REJECTED by BUDGET OWNER] | | {}
# Absence2[Declaration REJECTED by EMPLOYEE] | | {}
# Absence1[Declaration REJECTED by PRE_APPROVER] | | {}
# Absence1[Declaration APPROVED by PRE_APPROVER] | | {}
# Absence1[Declaration APPROVED by BUDGET OWNER] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {}
# Choice[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {}
# Choice[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Payment Handled] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Precedence[Payment Handled, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Absence1[Declaration SAVED by EMPLOYEE] | | {}
# Existence1[Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Request Payment] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Request Payment, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Init[Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 288, 0: 135, 3: 38, 4: 5, 6: 1, 7: 1, 5: 1}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {2: 312, 1: 288, 0: 135, 3: 37, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 289, 0: 135, 3: 37, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {2: 314, 1: 288, 0: 135, 3: 35, 4: 5, 5: 1, 6: 1, 7: 1}
# Not Chain Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {2: 309, 1: 293, 0: 135, 3: 36, 4: 5, 5: 1, 7: 1}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {2: 311, 1: 294, 0: 135, 3: 32, 4: 4, 5: 2, 6: 1, 7: 1}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {2: 304, 1: 297, 0: 135, 3: 36, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {1: 312, 2: 292, 0: 135, 3: 35, 4: 2, 5: 2, 6: 1, 7: 1}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {}
# Choice[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Request Payment] | | {}
# Choice[Request Payment, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {1: 323, 2: 284, 0: 135, 3: 34, 4: 2, 6: 1, 7: 1}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Payment Handled] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Existence1[Declaration REJECTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Request Payment] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by ADMINISTRATION] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Alternate Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration SUBMITTED by EMPLOYEE] | | {1: 531, 0: 181, 2: 62, 3: 5, 6: 1}
# Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {2: 307, 1: 246, 0: 181, 3: 38, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 182, 2: 62, 3: 5, 6: 1}
# Not Precedence[Request Payment, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 182, 2: 62, 3: 5, 6: 1}
# Not Precedence[Payment Handled, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 182, 2: 62, 3: 5, 6: 1}
# Not Precedence[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {1: 331, 2: 296, 0: 135, 3: 17, 4: 1}
# Not Precedence[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by EMPLOYEE] | | {1: 528, 0: 184, 2: 62, 3: 5, 6: 1}
# Not Chain Precedence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by EMPLOYEE] | | {1: 530, 0: 183, 2: 62, 3: 4, 6: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 536, 0: 181, 2: 57, 3: 5, 6: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {1: 295, 2: 282, 0: 160, 3: 35, 4: 4, 5: 2, 6: 1, 7: 1}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 280, 2: 272, 0: 191, 3: 33, 4: 2, 6: 1, 7: 1}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 320, 2: 274, 0: 148, 3: 33, 4: 3, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration FINAL_APPROVED by SUPERVISOR] | | {1: 293, 2: 286, 0: 160, 3: 33, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Precedence[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 520, 0: 192, 2: 62, 3: 5, 6: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 542, 0: 182, 2: 52, 3: 3, 6: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {1: 556, 0: 181, 2: 40, 3: 3}
# Absence2[Declaration APPROVED by ADMINISTRATION] | | {}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {1: 360, 2: 248, 0: 135, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by SUPERVISOR] | | {1: 557, 0: 182, 2: 38, 3: 3}
# Not Precedence[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 514, 0: 208, 2: 54, 3: 3, 6: 1}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 280, 2: 247, 0: 216, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 349, 2: 251, 0: 143, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 350, 2: 250, 0: 143, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 284, 2: 242, 0: 217, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 346, 2: 249, 0: 148, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 283, 2: 242, 0: 218, 3: 29, 4: 4, 5: 2, 6: 1, 7: 1}
# Absence1[Declaration REJECTED by ADMINISTRATION] | | {}
# Not Chain Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 502, 0: 222, 2: 53, 3: 2, 6: 1}
# Not Precedence[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {1: 502, 0: 224, 2: 51, 3: 2, 6: 1}
# Exclusive Choice[Declaration REJECTED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {1: 490, 0: 237, 2: 50, 3: 2, 6: 1}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by BUDGET OWNER] | | {}
# Exactly1[Declaration REJECTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 294, 0: 235, 2: 222, 3: 26, 4: 1, 6: 1, 7: 1}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 282, 0: 249, 2: 220, 3: 26, 4: 1, 6: 1, 7: 1}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 459, 0: 258, 2: 57, 3: 5, 6: 1}
# Exclusive Choice[Declaration APPROVED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by PRE_APPROVER] | | {1: 456, 0: 261, 2: 57, 3: 5, 6: 1}
# Not Chain Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 456, 0: 261, 2: 57, 3: 5, 6: 1}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {1: 455, 0: 262, 2: 57, 3: 5, 6: 1}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration REJECTED by PRE_APPROVER] | | {}
# Not Precedence[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {1: 455, 0: 262, 2: 57, 3: 5, 6: 1}
# Exclusive Choice[Declaration REJECTED by PRE_APPROVER, Declaration REJECTED by EMPLOYEE] | | {}
# Not Response[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 455, 0: 273, 2: 50, 3: 1, 6: 1}
# Absence1[Declaration APPROVED by ADMINISTRATION] | | {}
# Absence1[Declaration REJECTED by SUPERVISOR] | | {}
# Exclusive Choice[Declaration APPROVED by BUDGET OWNER, Declaration REJECTED by EMPLOYEE] | | {}
# Exclusive Choice[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {}
# Not Responded Existence[Declaration REJECTED by EMPLOYEE, Declaration APPROVED by BUDGET OWNER] | | {1: 443, 0: 291, 2: 44, 3: 1, 6: 1}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {}
# Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {}
# Absence1[Request Payment] | | {}
# Absence1[Payment Handled] | | {}
# Exclusive Choice[Declaration APPROVED by ADMINISTRATION, Declaration REJECTED by ADMINISTRATION] | | {}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration APPROVED by ADMINISTRATION] | | {}
# Not Precedence[Declaration APPROVED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {1: 483, 2: 144, 0: 135, 3: 16, 6: 1, 4: 1}
# Absence1[Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Precedence[Declaration REJECTED by SUPERVISOR, Declaration SUBMITTED by EMPLOYEE] | | {1: 489, 0: 135, 2: 135, 3: 18, 6: 1, 4: 1, 5: 1}
# Choice[Declaration REJECTED by SUPERVISOR, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration REJECTED by SUPERVISOR] | | {}
# Absence2[Declaration SUBMITTED by EMPLOYEE] | | {}
# Choice[Declaration FINAL_APPROVED by SUPERVISOR, Declaration APPROVED by ADMINISTRATION] | | {}
# Choice[Declaration APPROVED by ADMINISTRATION, Declaration FINAL_APPROVED by SUPERVISOR] | | {}
# Not Responded Existence[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {0: 370, 2: 283, 1: 109, 3: 17, 4: 1}
# Exclusive Choice[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {}
# Exclusive Choice[Declaration REJECTED by ADMINISTRATION, Declaration SUBMITTED by EMPLOYEE] | | {}
# Not Chain Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {0: 329, 2: 304, 1: 125, 3: 20, 4: 2}
# Not Response[Declaration SUBMITTED by EMPLOYEE, Declaration REJECTED by ADMINISTRATION] | | {0: 336, 2: 299, 1: 124, 3: 19, 4: 2}
# Choice[Declaration REJECTED by SUPERVISOR, Payment Handled] | | {}
# Choice[Payment Handled, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Request Payment, Declaration REJECTED by SUPERVISOR] | | {}
# Choice[Declaration REJECTED by SUPERVISOR, Request Payment] | | {}
